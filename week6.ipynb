# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#            Shop Name    Product Name Product Category  Quantity Sold  \
# 0         Urban Tech  Wireless Mouse             Tech              2
# 1       Daily Grocer    Organic Milk        Daily Use              5
# 2    The Snack Shack    Potato Chips           Snacks             12
# 3  Metro Electronics       USB Cable             Tech              8
# 4  Pantry Essentials       Dish Soap        Household              3
#
#    Price Per Unit  Total Sales
# 0           25.00        50.00
# 1            4.50        22.50
# 2            2.99        35.88
# 3            8.99        71.92
# 4            3.75        11.25
